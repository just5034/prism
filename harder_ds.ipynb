# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ## Google Colab Setup
# Run the cell below first to set up the environment.

# %%
# Google Colab Setup - Run this cell first!
import os

IN_COLAB = 'google.colab' in str(get_ipython()) if 'get_ipython' in dir() else False

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    DATA_DIR = '/content/drive/MyDrive/bioai_data'
    os.chdir(DATA_DIR)
    print(f"Working directory: {os.getcwd()}")
    print(f"Files available: {os.listdir('.')}")
else:
    print("Not running in Colab - using local paths")

# %%
import pandas as pd
# Load dataset
methexpr_df = pd.read_csv('ml_with_gene_expr.csv.gz',
compression='gzip',
index_col=0,
low_memory=False)
# Separate feature types
metadata_cols = ['primary site', 'primary histology', 'cosmic_id']
methylation_cols = [col for col in methexpr_df.columns if col.startswith('cg')]
expression_cols = [col for col in methexpr_df.columns if col.startswith('expr_')]
# Extract subsets
X_meth = methexpr_df[methylation_cols] # 1018 x 10000
X_expr = methexpr_df[expression_cols] # 1018 x 4956
metadata = methexpr_df[metadata_cols]

# %%
methexpr_df
# Out:
#                primary site          primary histology  cosmic_id  cg00944421  \
# 697                   blood     lymphoblastic_leukemia   906800.0    0.995309
# 5637      urogenital_system                    bladder   687452.0    0.010293
# 201T                   lung  lung_NSCLC_adenocarcinoma  1287381.0    0.821831
# 22RV1     urogenital_system                   prostate   924100.0    0.005373
# 23132-87   digestive_system                    stomach   910924.0    0.000000
# ...                     ...                        ...        ...         ...
# YAPC               pancreas                   pancreas   909904.0    0.009136
# YH-13        nervous_system                     glioma   909905.0    0.963341
# YKG-1        nervous_system                     glioma   687592.0    0.996477
# YT                    blood    lymphoid_neoplasm other   946358.0    1.000000
# ZR-75-30             breast                     breast   909907.0    0.003082
#
#           cg14557185  cg00989853  cg24702147  cg06723863  cg27174108  \
# 697         0.999933    0.992589    0.993804    1.000000    0.989910
# 5637        0.009700    0.000000    0.019619    0.001614    0.006393
# 201T        0.004671    0.091291    0.013206    0.016155    0.003981
# 22RV1       0.995386    0.000000    0.005776    0.004595    0.985648
# 23132-87    0.935833    0.000000    0.008962    0.002041    0.002005
# ...              ...         ...         ...         ...         ...
# YAPC        0.007066    0.000898    0.015999    0.014864    0.008737
# YH-13       0.005739    0.989838    0.992368    0.993164    0.989321
# YKG-1       0.007576    0.986879    0.996015    0.993360    0.996321
# YT          0.998999    0.998225    0.987221    1.000000    0.995139
# ZR-75-30    0.206821    0.000000    0.004853    0.002796    0.783043
#
#           cg14481208  ...  expr_JAM2  expr_SEPT1  expr_PEX7  expr_RFC5  \
# 697         0.991938  ...   5.239927    5.252104   6.627870   8.496907
# 5637        0.037711  ...   3.332692    3.060993   7.982724   7.489100
# 201T        0.008285  ...   2.868300    3.043228   8.197493   5.927889
# 22RV1       0.009981  ...   3.137277    3.234577   8.631361   7.250483
# 23132-87    0.026887  ...   3.104617    3.122160   9.548485   6.217373
# ...              ...  ...        ...         ...        ...        ...
# YAPC        0.019683  ...   3.160740    3.239356   7.852246   7.753827
# YH-13       0.982065  ...   4.127248    3.171536   7.192872   7.492028
# YKG-1       0.992586  ...   3.164598    3.154400   7.742972   6.738969
# YT          0.990399  ...   2.906149    5.274671   7.092308   7.250872
# ZR-75-30    0.028009  ...   3.038852    3.241425   8.852961   6.903248
#
#           expr_PENK  expr_ACSL3  expr_E2F3  expr_TM7SF3  expr_TTC14  \
# 697        2.766693    8.469268   7.597450     9.902359    6.926724
# 5637       2.894963    9.886996  10.607952     8.731725    5.143855
# 201T       2.624597   10.051639   5.640785     9.304462    7.920562
# 22RV1      2.815874    9.578729   5.241522     9.666908    7.436008
# 23132-87   2.824991    9.510297   5.226579    10.328542    6.025421
# ...             ...         ...        ...          ...         ...
# YAPC       2.996260   10.103385   6.098732     9.578503    6.843696
# YH-13      2.968564    8.663977   6.349145     8.770447    6.736737
# YKG-1      2.757865    8.894755   6.836061     9.024287    7.312585
# YT         3.009202    9.053290   6.760212    10.681652    8.856739
# ZR-75-30   2.745253   10.119246   6.599941     9.411871    7.058169
#
#           expr_SFT2D1
# 697          9.378083
# 5637         9.814031
# 201T        10.083233
# 22RV1        6.994852
# 23132-87    10.055381
# ...               ...
# YAPC        10.556830
# YH-13        9.609865
# YKG-1        9.803229
# YT           9.908252
# ZR-75-30     9.851917
#
# [987 rows x 15003 columns]

# %%
expression_cols
# Out:
# ['expr_RPS4Y1',
#  'expr_KRT19',
#  'expr_VIM',
#  'expr_S100P',
#  'expr_TACSTD2',
#  'expr_TGFBI',
#  'expr_TM4SF1',
#  'expr_SRGN',
#  'expr_CAV1',
#  'expr_DKK1',
#  'expr_C19orf33',
#  'expr_KRT8',
#  'expr_SPINT2',
#  'expr_NNMT',
#  'expr_EPCAM',
#  'expr_BEX1',
#  'expr_IFITM3',
#  'expr_UCHL1',
#  'expr_MYOF',
#  'expr_SPOCK1',
#  'expr_BASP1',
#  'expr_MAL2',
#  'expr_HLA-DRA',
#  'expr_CYR61',
#  'expr_DSP',
#  'expr_GNG11',
#  'expr_SLPI',
#  'expr_MGST1',
#  'expr_FN1',
#  'expr_PXDN',
#  'expr_HSPA1A',
#  'expr_SPP1',
#  'expr_LGALS1',
#  'expr_LGALS3',
#  'expr_BST2',
#  'expr_ANXA1',
#  'expr_NGFRAP1',
#  'expr_PRSS23',
#  'expr_IFI27',
#  'expr_TPD52L1',
#  'expr_GDF15',
#  'expr_ANXA3',
#  'expr_NUPR1',
#  'expr_KRT7',
#  'expr_S100A14',
#  'expr_S100A16',
#  'expr_LCN2',
#  'expr_MIR205HG',
#  'expr_EFEMP1',
#  'expr_SPARC',
#  'expr_AKR1C1',
#  'expr_BEX4',
#  'expr_UCA1',
#  'expr_HLA-DPA1',
#  'expr_TSPAN8',
#  'expr_GYPC',
#  'expr_LCP1',
#  'expr_ESRP1',
#  'expr_IGFBP3',
#  'expr_RAB25',
#  'expr_CYBA',
#  'expr_TUBB2B',
#  'expr_CAV2',
#  'expr_ALDH1A1',
#  'expr_CLEC2B',
#  'expr_TFPI',
#  'expr_ARHGDIB',
#  'expr_TSPAN1',
#  'expr_LAPTM5',
#  'expr_GPX2',
#  'expr_GMFG',
#  'expr_TMSB15A',
#  'expr_AKR1C2',
#  'expr_CTGF',
#  'expr_CXCR4',
#  'expr_VAMP8',
#  'expr_SNAI2',
#  'expr_S100A6',
#  'expr_IER3',
#  'expr_IFI16',
#  'expr_TESC',
#  'expr_TIMP3',
#  'expr_GAL',
#  'expr_AKR1C3',
#  'expr_CD9',
#  'expr_PRAME',
#  'expr_SCG2',
#  'expr_S100A10',
#  'expr_IGFBP6',
#  'expr_SRPX',
#  'expr_GTSF1',
#  'expr_CCL2',
#  'expr_C15orf48',
#  'expr_IGFBP2',
#  'expr_IL1A',
#  'expr_CNN3',
#  'expr_S100A4',
#  'expr_CLDN4',
#  'expr_NMU',
#  'expr_PLS3',
#  'expr_C3',
#  'expr_HTRA1',
#  'expr_IL8',
#  'expr_SERPINE2',
#  'expr_RAB34',
#  'expr_FGFBP1',
#  'expr_BMP4',
#  'expr_IFITM2',
#  'expr_COL1A2',
#  'expr_ID1',
#  'expr_SULF2',
#  'expr_SFN',
#  'expr_TUBB6',
#  'expr_TSPYL5',
#  'expr_S100A2',
#  'expr_MAP1B',
#  'expr_CTHRC1',
#  'expr_QPCT',
#  'expr_F3',
#  'expr_AKR1B10P1',
#  'expr_QPRT',
#  'expr_PLOD2',
#  'expr_FHL2',
#  'expr_S100A11',
#  'expr_PLBD1',
#  'expr_PLEK2',
#  'expr_INHBB',
#  'expr_NQO1',
#  'expr_CPE',
#  'expr_PYGL',
#  'expr_CTSZ',
#  'expr_C3orf14',
#  'expr_AKAP12',
#  'expr_CSTA',
#  'expr_GALNT3',
#  'expr_AKR1B10',
#  'expr_S100A9',
#  'expr_MX1',
#  'expr_HOXA9',
#  'expr_CD44',
#  'expr_C1S',
#  'expr_PLAU',
#  'expr_CXCL2',
#  'expr_ASS1',
#  'expr_RNF182',
#  'expr_DUSP4',
#  'expr_IGF2BP2',
#  'expr_ACTA2',
#  'expr_SERPINB1',
#  'expr_PTN',
#  'expr_BAMBI',
#  'expr_ERRFI1',
#  'expr_LUM',
#  'expr_PTGR1',
#  'expr_MMP1',
#  'expr_CD53',
#  'expr_CPVL',
#  'expr_ITGA2',
#  'expr_DFNA5',
#  'expr_FAT1',
#  'expr_VEGFC',
#  'expr_COL3A1',
#  'expr_SCG5',
#  'expr_CDH2',
#  'expr_TWIST1',
#  'expr_PLIN2',
#  'expr_TUBA1A',
#  'expr_PNMAL1',
#  'expr_CXCL1',
#  'expr_ITM2A',
#  'expr_TFF3',
#  'expr_CST6',
#  'expr_POU2AF1',
#  'expr_GSTP1',
#  'expr_HOXB2',
#  'expr_TNFSF10',
#  'expr_CMBL',
#  'expr_IL1B',
#  'expr_SDC2',
#  'expr_ELAVL2',
#  'expr_SGK1',
#  'expr_TNC',
#  'expr_FAM127A',
#  'expr_LAMA3',
#  'expr_NRN1',
#  'expr_BLNK',
#  'expr_SORL1',
#  'expr_MYLK',
#  'expr_TNFRSF11B',
#  'expr_CORO1A',
#  'expr_SLC27A2',
#  'expr_APOBEC3B',
#  'expr_RNF128',
#  'expr_CALD1',
#  'expr_AHNAK2',
#  'expr_SQRDL',
#  'expr_SMARCA1',
#  'expr_OCIAD2',
#  'expr_MLLT11',
#  'expr_SERPINE1',
#  'expr_TNNT1',
#  'expr_PLK2',
#  'expr_ESRP2',
#  'expr_TUSC3',
#  'expr_TNFRSF12A',
#  'expr_SEPP1',
#  'expr_PHLDA1',
#  'expr_BEX2',
#  'expr_KRT15',
#  'expr_CTSH',
#  'expr_IFIT1',
#  'expr_EMP3',
#  'expr_MDK',
#  'expr_RAB32',
#  'expr_PLAT',
#  'expr_KIF26A',
#  'expr_PMP22',
#  'expr_CA2',
#  'expr_COL17A1',
#  'expr_COL6A3',
#  'expr_AGR2',
#  'expr_GPR87',
#  'expr_DUSP6',
#  'expr_INSM1',
#  'expr_C8orf4',
#  'expr_KLF5',
#  'expr_KRT6A',
#  'expr_CD74',
#  'expr_CSAG1',
#  'expr_PYCARD',
#  'expr_FOS',
#  'expr_TIMP1',
#  'expr_COCH',
#  'expr_SDC4',
#  'expr_CEBPD',
#  'expr_CDH3',
#  'expr_ADORA2B',
#  'expr_KCNK1',
#  'expr_PALLD',
#  'expr_CTSL1',
#  'expr_PDLIM1',
#  'expr_TSPAN13',
#  'expr_LAPTM4B',
#  'expr_PMEPA1',
#  'expr_LRMP',
#  'expr_DSG2',
#  'expr_APOE',
#  'expr_CLDN1',
#  'expr_MMP7',
#  'expr_LPXN',
#  'expr_VCAN',
#  'expr_C1R',
#  'expr_IFI6',
#  'expr_TMEM98',
#  'expr_GPNMB',
#  'expr_CMTM7',
#  'expr_MEST',
#  'expr_ACSL5',
#  'expr_ALDH2',
#  'expr_FBXO32',
#  'expr_COL4A2',
#  'expr_EPSTI1',
#  'expr_RAB31',
#  'expr_ALOX5AP',
#  'expr_G0S2',
#  'expr_IL13RA2',
#  'expr_LGALS3BP',
#  'expr_FKBP10',
#  'expr_GPR160',
#  'expr_ARHGAP15',
#  'expr_RAMP1',
#  'expr_CHGA',
#  'expr_SYTL2',
#  'expr_DENND2D',
#  'expr_PPARG',
#  'expr_ADM',
#  'expr_SERPINB5',
#  'expr_GNG12',
#  'expr_FAM20C',
#  'expr_TIMP2',
#  'expr_CD68',
#  'expr_EIF1AY',
#  'expr_FLRT3',
#  'expr_ID2',
#  'expr_RARRES3',
#  'expr_ME1',
#  'expr_ALDH1A3',
#  'expr_DUSP5',
#  'expr_TPBG',
#  'expr_LOXL1',
#  'expr_KRTCAP3',
#  'expr_CAPG',
#  'expr_S100A13',
#  'expr_MAGEA4',
#  'expr_THBS1',
#  'expr_RND3',
#  'expr_KYNU',
#  'expr_RHOH',
#  'expr_TENM2',
#  'expr_IFI44L',
#  'expr_LY96',
#  'expr_RAB17',
#  'expr_CD52',
#  'expr_IGJ',
#  'expr_FAM83H',
#  'expr_CCND1',
#  'expr_MSN',
#  'expr_HSBP1L1',
#  'expr_P4HA2',
#  'expr_HLA-B',
#  'expr_LXN',
#  'expr_RARRES1',
#  'expr_KHDRBS3',
#  'expr_S100A8',
#  'expr_YAP1',
#  'expr_SUSD3',
#  'expr_PTX3',
#  'expr_PSMB9',
#  'expr_MOCOS',
#  'expr_PERP',
#  'expr_LDHB',
#  'expr_DPP4',
#  'expr_AP1M2',
#  'expr_CYP1B1',
#  'expr_HLA-C',
#  'expr_DCBLD2',
#  'expr_POSTN',
#  'expr_DUSP23',
#  'expr_RGCC',
#  'expr_MAGEC2',
#  'expr_JUP',
#  'expr_PDZK1IP1',
#  'expr_STMN3',
#  'expr_AXL',
#  'expr_SEMA3A',
#  'expr_GPRC5A',
#  'expr_P2RY8',
#  'expr_TCF4',
#  'expr_ISG20',
#  'expr_POPDC3',
#  'expr_CEACAM5',
#  'expr_TBC1D2',
#  'expr_KCNN4',
#  'expr_ARL4C',
#  'expr_CDKN2A',
#  'expr_TMEM158',
#  'expr_ITGA6',
#  'expr_SYT1',
#  'expr_GCNT3',
#  'expr_TFF1',
#  'expr_CENPV',
#  'expr_COL5A1',
#  'expr_BCL2A1',
#  'expr_LAYN',
#  'expr_STC2',
#  'expr_ARMCX2',
#  'expr_VAMP5',
#  'expr_NCKAP1',
#  'expr_RPL39L',
#  'expr_KRT5',
#  'expr_ANXA10',
#  'expr_CNRIP1',
#  'expr_TMEM47',
#  'expr_MGLL',
#  'expr_PIR',
#  'expr_ID3',
#  'expr_ISG15',
#  'expr_RGS20',
#  'expr_DNER',
#  'expr_SLFN11',
#  'expr_XIST',
#  'expr_IGF2',
#  'expr_TMC4',
#  'expr_ANKRD1',
#  'expr_SERPINF1',
#  'expr_EDN1',
#  'expr_IRX3',
#  'expr_EMP1',
#  'expr_COL11A1',
#  'expr_HSPA2',
#  'expr_FST',
#  'expr_LYZ',
#  'expr_GPX8',
#  'expr_ALPK2',
#  'expr_APOC1',
#  'expr_ASCL1',
#  'expr_INHBE',
#  'expr_PCP4',
#  'expr_NT5E',
#  'expr_ADAMTS1',
#  'expr_HTATIP2',
#  'expr_DOCK11',
#  'expr_SLC35G2',
#  'expr_SPATS2L',
#  'expr_DDX3Y',
#  'expr_KDELR3',
#  'expr_ST6GALNAC2',
#  'expr_TMEM45A',
#  'expr_LINC00341',
#  'expr_MFAP2',
#  'expr_ITPRIPL2',
#  'expr_RGS2',
#  'expr_AMIGO2',
#  'expr_CA12',
#  'expr_NEFL',
#  'expr_FAM213A',
#  'expr_SERPINB6',
#  'expr_CLIC3',
#  'expr_BCL11B',
#  'expr_WBP5',
#  'expr_PAPSS2',
#  'expr_SERPINH1',
#  'expr_CD40',
#  'expr_DDX60',
#  'expr_NFKBIZ',
#  'expr_SAMD9',
#  'expr_GLB1L2',
#  'expr_PSMB8',
#  'expr_PTPRC',
#  'expr_COL7A1',
#  'expr_CDH1',
#  'expr_FSTL1',
#  'expr_AIM2',
#  'expr_POU4F1',
#  'expr_PON2',
#  'expr_MARCKS',
#  'expr_RAB38',
#  'expr_GSN',
#  'expr_TUBA4A',
#  'expr_CDS1',
#  'expr_NREP',
#  'expr_VGF',
#  'expr_FAP',
#  'expr_MGMT',
#  'expr_ADRB2',
#  'expr_SYCP2',
#  'expr_PROCR',
#  'expr_BIRC3',
#  'expr_ST14',
#  'expr_RRAGD',
#  'expr_GATA3',
#  'expr_ZBED2',
#  'expr_COL4A1',
#  'expr_TFPI2',
#  'expr_MYC',
#  'expr_CCDC80',
#  'expr_KRT23',
#  'expr_LPHN2',
#  'expr_CCL20',
#  'expr_TRIP6',
#  'expr_DTX4',
#  'expr_TRIB2',
#  'expr_IFI30',
#  'expr_CCND2',
#  'expr_HES6',
#  'expr_TRBC2',
#  'expr_GLDC',
#  'expr_FLNC',
#  'expr_CD70',
#  'expr_ID4',
#  'expr_AGPAT9',
#  'expr_RHOBTB3',
#  'expr_RARRES2',
#  'expr_GPX7',
#  'expr_SLC16A4',
#  'expr_ATP1B1',
#  'expr_BATF',
#  'expr_EGR1',
#  'expr_GRP',
#  'expr_PLCG2',
#  'expr_CKB',
#  'expr_SH3BGRL',
#  'expr_IGHM',
#  'expr_EBF1',
#  'expr_ENPP2',
#  'expr_DLC1',
#  'expr_CALB1',
#  'expr_AEBP1',
#  'expr_LOX',
#  'expr_RGS4',
#  'expr_CSDA',
#  'expr_MAGEB2',
#  'expr_CDC42EP3',
#  'expr_ANXA6',
#  'expr_PRKCB',
#  'expr_TXNIP',
#  'expr_BACE2',
#  'expr_LDOC1',
#  'expr_STEAP1',
#  'expr_LAMA1',
#  'expr_GPRC5C',
#  'expr_SIPA1L2',
#  'expr_GAS6',
#  'expr_GSTA4',
#  'expr_FBXL16',
#  'expr_LYN',
#  'expr_PLAUR',
#  'expr_LAMB3',
#  'expr_PPIC',
#  'expr_FOXQ1',
#  'expr_PTPRM',
#  'expr_HOXD8',
#  'expr_BTK',
#  'expr_TCEAL3',
#  'expr_KRT14',
#  'expr_TSPAN6',
#  'expr_ITGB2',
#  'expr_SAMSN1',
#  'expr_SEL1L3',
#  'expr_IRF8',
#  'expr_EPPK1',
#  'expr_PHLDA2',
#  'expr_LIMCH1',
#  'expr_PPAP2C',
#  'expr_CXCL5',
#  'expr_TMSB15B',
#  'expr_TAGLN',
#  'expr_FAM129A',
#  'expr_RHOD',
#  'expr_BMP7',
#  'expr_SGCE',
#  'expr_HENMT1',
#  'expr_PHGDH',
#  'expr_LEPREL1',
#  'expr_CD55',
#  'expr_MT2A',
#  'expr_GLIPR1',
#  'expr_PVRL3',
#  'expr_CCNA1',
#  'expr_CHN1',
#  'expr_SERPINA3',
#  'expr_PRTFDC1',
#  'expr_FAM92A1P1',
#  'expr_PI3',
#  'expr_PLEK',
#  'expr_MZB1',
#  'expr_ANXA4',
#  'expr_FYN',
#  'expr_CYTL1',
#  'expr_ENAH',
#  'expr_ERP27',
#  'expr_LCP2',
#  'expr_TNFAIP3',
#  'expr_AK4',
#  'expr_APP',
#  'expr_GCHFR',
#  'expr_THY1',
#  'expr_TJP1',
#  'expr_STC1',
#  'expr_SNX7',
#  'expr_DACH1',
#  'expr_ICA1',
#  'expr_CHI3L1',
#  'expr_KLK8',
#  'expr_MYB',
#  'expr_TM4SF4',
#  'expr_TUBB2A',
#  'expr_MS4A1',
#  'expr_GIMAP2',
#  'expr_ARHGEF5',
#  'expr_ITGB5',
#  'expr_ATP8B1',
#  'expr_PLEKHO1',
#  'expr_MYO1B',
#  'expr_FAM64A',
#  'expr_SAA1',
#  'expr_PMEL',
#  'expr_NEURL1B',
#  'expr_TOX3',
#  'expr_IGFBP5',
#  'expr_SYK',
#  'expr_FAM210B',
#  'expr_ATF5',
#  'expr_HOOK1',
#  'expr_SOGA2',
#  'expr_PRSS21',
#  'expr_MGST2',
#  'expr_CCL5',
#  'expr_GNG4',
#  'expr_ONECUT2',
#  'expr_SPRY2',
#  'expr_GAS1',
#  'expr_XYLT1',
#  'expr_UBE2L6',
#  'expr_PRSS3',
#  'expr_CLDN3',
#  'expr_CAMK2N1',
#  'expr_SELENBP1',
#  'expr_VCAM1',
#  'expr_S100B',
#  'expr_STMN2',
#  'expr_WWTR1',
#  'expr_RGS16',
#  'expr_MITF',
#  'expr_PCDHB5',
#  'expr_ASPHD1',
#  'expr_TAGLN3',
#  'expr_NCF4',
#  'expr_BCHE',
#  'expr_COL9A3',
#  'expr_COLEC12',
#  'expr_REC8',
#  'expr_LURAP1L',
#  'expr_HOXB7',
#  'expr_MATN2',
#  'expr_GPC4',
#  'expr_TNFAIP6',
#  'expr_RRAS',
#  'expr_HHEX',
#  'expr_PLAC8',
#  'expr_TCN1',
#  'expr_CD82',
#  'expr_PTGS2',
#  'expr_STEAP2',
#  'expr_ENC1',
#  'expr_MAP2',
#  'expr_ECHDC3',
#  'expr_NTS',
#  'expr_RAB33A',
#  'expr_PRKD1',
#  'expr_HMCN1',
#  'expr_LRRC17',
#  'expr_PROSER2',
#  'expr_CD48',
#  'expr_SLIT2',
#  'expr_FHL1',
#  'expr_HERC5',
#  'expr_FERMT2',
#  'expr_CTSL2',
#  'expr_PRR15',
#  'expr_CKAP4',
#  'expr_TRIM22',
#  'expr_ANK3',
#  'expr_RASEF',
#  'expr_CYB5R2',
#  'expr_C12orf75',
#  'expr_NR2F2',
#  'expr_IFIT3',
#  'expr_COL4A5',
#  'expr_SIK1',
#  'expr_ADCY1',
#  'expr_ADA',
#  'expr_SERTAD4',
#  'expr_CTSS',
#  'expr_HEPACAM2',
#  'expr_SOWAHC',
#  'expr_RAB20',
#  'expr_ALDH3A1',
#  'expr_MEF2C',
#  'expr_TES',
#  'expr_GLI3',
#  'expr_NELL2',
#  'expr_GATA6',
#  'expr_CAPN2',
#  'expr_KRT20',
#  'expr_ZNF83',
#  'expr_OVOL2',
#  'expr_PABPC4L',
#  'expr_ZEB1',
#  'expr_ARHGAP23',
#  'expr_CEACAM6',
#  'expr_HSD17B2',
#  'expr_RFTN1',
#  'expr_OAS1',
#  'expr_WNT10A',
#  'expr_FBP1',
#  'expr_DHRS2',
#  'expr_PLA2G4A',
#  'expr_PHGR1',
#  'expr_SFRP1',
#  'expr_PLS1',
#  'expr_SERPINA1',
#  'expr_OASL',
#  'expr_KRT13',
#  'expr_TYRP1',
#  'expr_DEPTOR',
#  'expr_CFD',
#  'expr_TMEM51',
#  'expr_MT1A',
#  'expr_SNCA',
#  'expr_MNX1',
#  'expr_CASP4',
#  'expr_DPYSL3',
#  'expr_MXRA5',
#  'expr_GLRX',
#  'expr_AHNAK',
#  'expr_LAMC2',
#  'expr_UPP1',
#  'expr_SDPR',
#  'expr_MAGED1',
#  'expr_MMP14',
#  'expr_EMC10',
#  'expr_LSR',
#  'expr_ANKRD22',
#  'expr_EFEMP2',
#  'expr_TRIM2',
#  'expr_DDR2',
#  'expr_PPAP2B',
#  'expr_SDC1',
#  'expr_BMP2',
#  'expr_CST3',
#  'expr_SOX9',
#  'expr_MAGEH1',
#  'expr_NR0B1',
#  'expr_PRRX1',
#  'expr_SLAIN1',
#  'expr_KRTAP2-3',
#  'expr_FAR2',
#  'expr_CYFIP2',
#  'expr_TNFRSF21',
#  'expr_RASGEF1A',
#  'expr_RNF130',
#  'expr_CHST11',
#  'expr_SLC16A3',
#  'expr_SERPINI1',
#  'expr_DYNLT3',
#  'expr_IL18',
#  'expr_PRKCDBP',
#  'expr_THSD7A',
#  'expr_PDGFC',
#  'expr_TCL1A',
#  'expr_COL16A1',
#  'expr_GALNT14',
#  'expr_RGS13',
#  'expr_ISL1',
#  'expr_PCLO',
#  'expr_TLE1',
#  'expr_MT1E',
#  'expr_CD99',
#  'expr_FAM134B',
#  'expr_NLRP2',
#  'expr_NFIB',
#  'expr_FOXG1',
#  'expr_COL18A1',
#  'expr_MPZL2',
#  'expr_ST6GAL1',
#  'expr_PCOLCE2',
#  'expr_KCNMB4',
#  'expr_ELF3',
#  'expr_AVPI1',
#  'expr_DOCK10',
#  'expr_SERINC2',
#  'expr_EVI2B',
#  'expr_CDK6',
#  'expr_NRIP1',
#  'expr_THBS2',
#  'expr_NAPRT1',
#  'expr_PITX2',
#  'expr_STAMBPL1',
#  'expr_CMTM3',
#  'expr_STOM',
#  'expr_GOLT1A',
#  'expr_BDNF',
#  'expr_FZD2',
#  'expr_PRDX2',
#  'expr_FAM46A',
#  'expr_BIK',
#  'expr_CD38',
#  'expr_PCDHB2',
#  'expr_ZIC2',
#  'expr_HPGD',
#  'expr_ICAM1',
#  'expr_PMAIP1',
#  'expr_LTBR',
#  'expr_UGT2B7',
#  'expr_EXT1',
#  'expr_TOR4A',
#  'expr_ZG16B',
#  'expr_TNFRSF17',
#  'expr_CNKSR3',
#  'expr_SIX4',
#  'expr_FGF13',
#  'expr_EPB41L2',
#  'expr_DUSP2',
#  'expr_NETO2',
#  'expr_ELAVL4',
#  'expr_MYBL1',
#  'expr_NTN4',
#  'expr_HLA-DRB1',
#  'expr_SRPX2',
#  'expr_FOXF2',
#  'expr_CFH',
#  'expr_EFNA1',
#  'expr_GULP1',
#  'expr_CSRP2',
#  'expr_KIAA1324L',
#  'expr_TGIF1',
#  'expr_DCT',
#  'expr_MT1G',
#  'expr_TSPAN12',
#  'expr_FAM43A',
#  'expr_ANXA2',
#  'expr_FAM129B',
#  'expr_COL5A2',
#  'expr_CDCA7L',
#  'expr_IRS2',
#  'expr_SULF1',
#  'expr_COPZ2',
#  'expr_GOLGA8A',
#  'expr_HOXC4',
#  'expr_PIK3AP1',
#  'expr_DNAJC12',
#  'expr_MLANA',
#  'expr_MOK',
#  'expr_STEAP1B',
#  'expr_KCNS3',
#  'expr_VSNL1',
#  'expr_FUCA2',
#  'expr_GSTT1',
#  'expr_TUSC1',
#  'expr_TMEM246',
#  'expr_TXLNG2P',
#  'expr_PRICKLE1',
#  'expr_LMO2',
#  'expr_RTN1',
#  'expr_NUDT11',
#  'expr_OLFM1',
#  'expr_LY86',
#  'expr_NOL4',
#  'expr_NDN',
#  'expr_CST7',
#  'expr_KLF4',
#  'expr_FRMD6',
#  'expr_NMI',
#  'expr_MT1F',
#  'expr_LGALS4',
#  'expr_KCNMA1',
#  'expr_GBP3',
#  'expr_DNAJC15',
#  'expr_FAS',
#  'expr_TSPO',
#  'expr_INPP1',
#  'expr_ETS2',
#  'expr_HSPB8',
#  'expr_MSL3P1',
#  'expr_FAM101B',
#  'expr_DCDC2',
#  'expr_PKIB',
#  'expr_TYR',
#  'expr_TSPAN7',
#  'expr_SOX4',
#  'expr_RBM47',
#  'expr_CDKN2C',
#  'expr_A2M',
#  'expr_NRIP3',
#  'expr_GRB10',
#  'expr_HES4',
#  'expr_SOCS2',
#  'expr_PROS1',
#  'expr_PLCB4',
#  'expr_FOXC1',
#  'expr_RAB13',
#  'expr_ABCC3',
#  'expr_ST3GAL6',
#  'expr_PTGFRN',
#  'expr_PCDH9',
#  'expr_PDGFRA',
#  'expr_AZGP1',
#  'expr_CBS',
#  'expr_RGS5',
#  'expr_TGFB1I1',
#  'expr_ARNTL2',
#  'expr_IRX2',
#  'expr_CDCP1',
#  'expr_SAT1',
#  'expr_GNAI1',
#  'expr_MARC1',
#  'expr_AP1S2',
#  'expr_VLDLR',
#  'expr_TTC28',
#  'expr_ALX1',
#  'expr_CFI',
#  'expr_LARP6',
#  'expr_MX2',
#  'expr_SKAP2',
#  'expr_HOPX',
#  'expr_HLA-E',
#  'expr_WASF3',
#  'expr_BCAR3',
#  'expr_CD302',
#  'expr_WIPI1',
#  'expr_MECOM',
#  'expr_FAT3',
#  'expr_SAMD5',
#  'expr_ABLIM1',
#  'expr_XAF1',
#  'expr_SACS',
#  'expr_TBC1D8',
#  'expr_NID2',
#  'expr_FADS1',
#  'expr_FOXA1',
#  'expr_GBP2',
#  'expr_CTBP2',
#  'expr_RBP7',
#  'expr_FZD6',
#  'expr_NCF2',
#  'expr_SOX11',
#  'expr_CXXC5',
#  'expr_ARMCX1',
#  'expr_EYA4',
#  'expr_DKK3',
#  'expr_POU3F2',
#  'expr_GPX1',
#  'expr_OLFML3',
#  'expr_DSG3',
#  'expr_MAB21L1',
#  'expr_GPR18',
#  'expr_EMB',
#  'expr_MAFB',
#  'expr_FAM107B',
#  'expr_ARID5B',
#  'expr_RHOV',
#  'expr_BEX5',
#  'expr_TSPAN5',
#  'expr_LAT2',
#  'expr_DHRS9',
#  'expr_SLC7A7',
#  'expr_RAI14',
#  'expr_EPHA2',
#  'expr_CDH13',
#  'expr_ZFP82',
#  'expr_FAM83A',
#  'expr_BAIAP2L1',
#  'expr_MME',
#  'expr_ARHGAP30',
#  'expr_GALNT5',
#  'expr_CTH',
#  'expr_TCEAL4',
#  'expr_TNNC1',
#  'expr_HYI',
#  'expr_TRNP1',
#  'expr_TGM2',
#  'expr_DUSP1',
#  'expr_WLS',
#  'expr_CTSB',
#  'expr_FXYD5',
#  'expr_FOXF1',
#  'expr_FAM127B',
#  'expr_GATM',
#  'expr_RHOF',
#  'expr_IL17RB',
#  'expr_PTPRF',
#  'expr_HGD',
#  'expr_NRXN3',
#  'expr_MOXD1',
#  'expr_CRISPLD1',
#  'expr_CYBRD1',
#  'expr_PLEKHA1',
#  'expr_ZNF711',
#  'expr_PRR15L',
#  'expr_EVI2A',
#  'expr_RIN2',
#  'expr_DDX60L',
#  'expr_FERMT1',
#  'expr_JUN',
#  'expr_IL7R',
#  'expr_PRNP',
#  'expr_IMPA2',
#  'expr_PRSS8',
#  'expr_CADM1',
#  'expr_GSTO2',
#  'expr_LITAF',
#  'expr_EAF2',
#  'expr_CXCR7',
#  'expr_LRRN3',
#  'expr_CRYAB',
#  'expr_OPN3',
#  'expr_CELF2',
#  'expr_RHOU',
#  'expr_ZNF467',
#  'expr_MYL9',
#  'expr_GEM',
#  'expr_ACTN1',
#  'expr_GUCY1B3',
#  'expr_LAMC1',
#  'expr_CBR3',
#  'expr_ADSSL1',
#  'expr_NPDC1',
#  'expr_FAM174B',
#  'expr_CDA',
#  'expr_FKBP1B',
#  'expr_METTL7B',
#  'expr_LYPD6B',
#  'expr_CHCHD10',
#  'expr_HSD17B8',
#  'expr_MLPH',
#  'expr_SRSF12',
#  'expr_PNPLA3',
#  'expr_ABI3BP',
#  'expr_FERMT3',
#  'expr_BCAT1',
#  'expr_IFNLR1',
#  'expr_CPQ',
#  'expr_PDP1',
#  'expr_SCIN',
#  'expr_RBMS1',
#  'expr_HLA-DQA1',
#  'expr_TSPAN4',
#  'expr_PLLP',
#  'expr_PLAGL1',
#  ...]

# %%
response_df = pd.read_csv('ML_dataset_methylation_drug_response.csv.gz',
				 compression='gzip',
				 index_col=0,
				 low_memory=False)


drug_cols = [col for col in response_df.columns if col not in metadata_cols and col not in methylation_cols]

y_all_drugs = response_df[drug_cols]  # 1018 x 265

y_all_drugs

# %%
df = methexpr_df.join(y_all_drugs, how='inner', lsuffix='_caller', rsuffix='_other')
df
# Out:
#                primary site        primary histology  cosmic_id  cg00944421  \
# 697                   blood   lymphoblastic_leukemia   906800.0    0.995309
# 5637      urogenital_system                  bladder   687452.0    0.010293
# 22RV1     urogenital_system                 prostate   924100.0    0.005373
# 23132-87   digestive_system                  stomach   910924.0    0.000000
# 42-MG-BA     nervous_system                   glioma   687561.0    0.994996
# ...                     ...                      ...        ...         ...
# YAPC               pancreas                 pancreas   909904.0    0.009136
# YH-13        nervous_system                   glioma   909905.0    0.963341
# YKG-1        nervous_system                   glioma   687592.0    0.996477
# YT                    blood  lymphoid_neoplasm other   946358.0    1.000000
# ZR-75-30             breast                   breast   909907.0    0.003082
#
#           cg14557185  cg00989853  cg24702147  cg06723863  cg27174108  \
# 697         0.999933    0.992589    0.993804    1.000000    0.989910
# 5637        0.009700    0.000000    0.019619    0.001614    0.006393
# 22RV1       0.995386    0.000000    0.005776    0.004595    0.985648
# 23132-87    0.935833    0.000000    0.008962    0.002041    0.002005
# 42-MG-BA    0.000000    1.000000    1.000000    1.000000    1.000000
# ...              ...         ...         ...         ...         ...
# YAPC        0.007066    0.000898    0.015999    0.014864    0.008737
# YH-13       0.005739    0.989838    0.992368    0.993164    0.989321
# YKG-1       0.007576    0.986879    0.996015    0.993360    0.996321
# YT          0.998999    0.998225    0.987221    1.000000    0.995139
# ZR-75-30    0.206821    0.000000    0.004853    0.002796    0.783043
#
#           cg14481208  ...     ZG-10     ZL049     ZL109  ZM447439   ZSTK474  \
# 697         0.991938  ...       NaN  1.389685 -1.238606 -0.364143 -2.428664
# 5637        0.037711  ...       NaN  2.053874  0.046212  0.556022  0.239659
# 22RV1       0.009981  ...  2.216771  3.456567  0.704177  3.415833 -0.571660
# 23132-87    0.026887  ...       NaN  3.582629 -0.153728  3.171768  0.052341
# 42-MG-BA    0.995498  ...       NaN  2.995327 -0.980930  1.339098  2.235509
# ...              ...  ...       ...       ...       ...       ...       ...
# YAPC        0.019683  ...       NaN  5.121817  1.659229  2.946571  2.190982
# YH-13       0.982065  ...  0.712498  2.348748 -0.409551  1.514446  0.242131
# YKG-1       0.992586  ...       NaN  2.297815 -0.086315  1.239723  0.718917
# YT          0.990399  ...       NaN  2.737701  0.298806  1.466147 -3.425817
# ZR-75-30    0.028009  ...  2.501363  4.726344  0.649065  5.048494 -1.907806
#
#           Zibotentan  eEF2K Inhibitor, A-484954  kb NB 142-70    rTRAIL  \
# 697         4.825729                   4.690386      0.684583 -3.045563
# 5637        5.144572                   5.273391      2.519340 -2.889220
# 22RV1       5.886388                   5.891054      2.989656 -0.586829
# 23132-87    5.419213                   5.460743      2.988242 -0.347357
# 42-MG-BA    5.494359                   5.566457      3.082294 -1.651262
# ...              ...                        ...           ...       ...
# YAPC        6.153842                   6.538489      3.625790 -1.416428
# YH-13       5.164013                   5.539282      1.610461  0.131337
# YKG-1       5.048165                   5.600037      2.003123 -1.560052
# YT          5.165823                   5.211461      1.620578 -0.557084
# ZR-75-30    6.535959                   5.594594      3.471667  1.059619
#
#             torin2
# 697            NaN
# 5637           NaN
# 22RV1          NaN
# 23132-87       NaN
# 42-MG-BA       NaN
# ...            ...
# YAPC           NaN
# YH-13          NaN
# YKG-1          NaN
# YT             NaN
# ZR-75-30  2.226058
#
# [901 rows x 15378 columns]

# %%
drug = 'Avagacestat'
y = df[drug].dropna()  # Remove missing values
y
# Out:
# 697         3.541041
# 5637        4.040710
# 22RV1       3.515197
# 23132-87    4.091940
# 42-MG-BA    4.047185
#               ...
# YAPC        4.613361
# YH-13       4.222055
# YKG-1       4.418124
# YT          2.715923
# ZR-75-30    5.503293
# Name: Avagacestat, Length: 896, dtype: float64

# %%
feature_cols = methylation_cols + expression_cols + ['primary histology']
X = df[feature_cols]
X_subset = X.loc[y.index].dropna(axis=1)  # Ensure no NaNs in features as well
y_subset = y.loc[X_subset.index]

# %% [markdown]
# ## Train-Test Split Strategy: Histology-Based (Harder Problem)
#
# **Goal**: Test model's ability to generalize to **unseen cancer subtypes**
#
# **Method**: Split by `primary histology` - put rare cancer subtypes in test set
# - Train on common cancer types (e.g., glioma, melanoma, lung adenocarcinoma)
# - Test on rare types the model has never seen (e.g., chondrosarcoma, fibrosarcoma)
#
# **Threshold**: 40% of histology types → ~9% of samples in test set

# %% [markdown]
# Sort by type

# %%
counts = X_subset['primary histology'].value_counts(ascending=True)
pd.DataFrame(counts)
# Out:
#                                     count
# primary histology
# digestive_system_other                  1
# adrenal_gland                           1
# Lung_other                              1
# bone_other                              2
# testis                                  2
# uterus                                  2
# skin_other                              3
# chondrosarcoma                          3
# hairy_cell_leukaemia                    3
# fibrosarcoma                            3
# leukemia                                3
# anaplastic_large_cell_lymphoma          3
# lung_NSCLC_carcinoid                    4
# urogenital_system_other                 4
# T_cell_leukemia                         4
# medulloblastoma                         4
# biliary_tract                           4
# haematopoietic_neoplasm other           5
# mesothelioma                            6
# Hodgkin_lymphoma                        7
# prostate                                7
# lymphoblastic_T_cell_leukaemia          8
# soft_tissue_other                       8
# rhabdomyosarcoma                        9
# osteosarcoma                           10
# chronic_myeloid_leukaemia              10
# lymphoid_neoplasm other                10
# lung_NSCLC_not specified               11
# endometrium                            11
# lymphoblastic_leukemia                 12
# myeloma                                12
# B_cell_leukemia                        12
# lung_NSCLC_large cell                  13
# Burkitt_lymphoma                       13
# thyroid                                14
# lung_NSCLC_squamous_cell_carcinoma     14
# cervix                                 14
# liver                                  16
# bladder                                18
# ewings_sarcoma                         19
# stomach                                23
# acute_myeloid_leukaemia                24
# neuroblastoma                          29
# B_cell_lymphoma                        30
# pancreas                               30
# kidney                                 31
# oesophagus                             35
# head and neck                          39
# ovary                                  40
# large_intestine                        43
# breast                                 49
# melanoma                               50
# glioma                                 50
# lung_small_cell_carcinoma              55
# lung_NSCLC_adenocarcinoma              62

# %%
counts.shape[0]
# Out:
# 55

# %%
# Split threshold: 40% of histology types go to test (the rarest ones)
SPLIT_THRESHOLD = 0.4

split_index = int(counts.shape[0] * SPLIT_THRESHOLD)
test_split = counts.index[:split_index]  # Rarest histology types
train_split = counts.index[split_index:]  # More common types

print(f"Splitting {len(counts)} histology types at {SPLIT_THRESHOLD*100:.0f}% threshold")
print(f"Test types: {split_index} (rare cancers model has NEVER seen)")
print(f"Train types: {len(counts) - split_index}")

X_train = X_subset[X_subset['primary histology'].isin(train_split)].drop(columns=['primary histology'])
y_train = y_subset[X_train.index]	
X_test = X_subset[X_subset['primary histology'].isin(test_split)].drop(columns=['primary histology'])
y_test = y_subset[X_test.index]

print(f"\nTrain samples: {len(X_train)} ({len(X_train)/len(X_subset)*100:.1f}%)")
print(f"Test samples: {len(X_test)} ({len(X_test)/len(X_subset)*100:.1f}%)")
print(f"\nTest histology types: {list(test_split)}")

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
def add_benchmark_result(model, model_name, X_test, y_test, X_train, y_train):
	# Training performance
	y_pred_train = model.predict(X_train)
	testing_mse = -cross_val_score(model, X_test, y_test, cv=5, scoring='neg_mean_squared_error')
	training_mse = mean_squared_error(y_train, y_pred_train)
	training_r2 = r2_score(y_train, y_pred_train)
	testing_r2 = r2_score(y_test, model.predict(X_test))

	return [model_name, training_mse, testing_mse.mean(), training_r2, testing_r2]

# %%
benchmark_results = pd.DataFrame(columns=['Model', 'training MSE', 'average testing MSE', 'training R^2','testing R^2'])

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler

# %%
pca = PCA(n_components=15)
x_scaler = RobustScaler()

# IMPORTANT: Scale before PCA (methylation: 0-1, expression: 2-14 - different scales!)
X_train_scaled = x_scaler.fit_transform(X_train)
X_train_scaled = pca.fit_transform(X_train_scaled)

X_test_scaled = x_scaler.transform(X_test)
X_test_scaled = pca.transform(X_test_scaled)

# %% [markdown]
# ## Re-run w/ results

# %%
from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingRandomSearchCV, HalvingGridSearchCV

# %% [markdown]
# ## boosted Trees

# %%
from xgboost import XGBRegressor
# GPU-enabled XGBoost (uses T4 in Colab)
xgb_model = XGBRegressor(random_state=42, tree_method='hist', device='cuda')
param_grid = {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7]
    }
search = HalvingRandomSearchCV(
	xgb_model, param_grid, factor=2,
	min_resources=50, max_resources=300, scoring='neg_mean_absolute_error',
	cv=3, n_jobs=1, verbose=1, random_state=42  # n_jobs=1 since GPU handles parallelism
)
search.fit(X_train_scaled, y_train)
print(search.best_params_, search.best_score_)

# %%
model = search.best_estimator_
benchmark_results.loc[len(benchmark_results)] = add_benchmark_result(model, 'XGBoost w/ PCA', X_test_scaled, y_test, X_train_scaled, y_train)
benchmark_results
# Out:
#             Model  training MSE  average testing MSE  training R^2  \
# 0  XGBoost w/ PCA      0.348347              0.23945      0.167791
#
#    testing R^2
# 0    -0.064205

# %%
from xgboost import XGBRegressor
# GPU-enabled XGBoost (uses T4 in Colab)
xgb_model = XGBRegressor(random_state=42, tree_method='hist', device='cuda')
param_grid = {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7]
    }
search = HalvingRandomSearchCV(
	xgb_model, param_grid, factor=2,
	min_resources=50, max_resources=300, scoring='neg_mean_absolute_error',
	cv=3, n_jobs=1, verbose=3, random_state=42  # n_jobs=1 since GPU handles parallelism
)
search.fit(X_train, y_train)
print(search.best_params_, search.best_score_)

# %%
benchmark_results.loc[len(benchmark_results)] = add_benchmark_result(search.best_estimator_, 'XGBoost', X_test, y_test, X_train, y_train)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import randint, uniform

# %%
rf = RandomForestRegressor(random_state=42, n_jobs=-1)
param_dist = {
    "n_estimators": randint(50, 300),
    "max_depth": randint(3, 30),
    "min_samples_split": randint(2, 10),
    "min_samples_leaf": randint(1, 6),
    "max_features": uniform(0.3, 0.7),
    "bootstrap": [True, False],
}
search = HalvingRandomSearchCV(
    rf, param_dist, factor=2,
    min_resources=50, max_resources=300,scoring='neg_mean_absolute_error',
	cv=3, n_jobs=-1, verbose=1, random_state=42
)
search.fit(X_train_scaled, y_train)
print(search.best_params_, search.best_score_)
# Out:
# n_iterations: 3
# n_required_iterations: 3
# n_possible_iterations: 3
# min_resources_: 50
# max_resources_: 300
# aggressive_elimination: False
# factor: 2
# ----------
# iter: 0
# n_candidates: 6
# n_resources: 50
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# ----------
# iter: 1
# n_candidates: 3
# n_resources: 100
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# ----------
# iter: 2
# n_candidates: 2
# n_resources: 200
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# {'bootstrap': True, 'max_depth': 3, 'max_features': np.float64(0.5129695700716763), 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 138} -0.5273315049839368

# %%
model = search.best_estimator_

# %%
benchmark_results.loc[len(benchmark_results)] = add_benchmark_result(model, 'Random Forest w/ PCA', X_test_scaled, y_test, X_train_scaled, y_train)
benchmark_results
# Out:
#                   Model  training MSE  average testing MSE  training R^2  \
# 0        XGBoost w/ PCA      0.348347             0.239450      0.167791
# 1               XGBoost      0.298308             0.308423      0.287336
# 2  Random Forest w/ PCA      0.343904             0.245486      0.178404
#
#    testing R^2
# 0    -0.064205
# 1    -0.029302
# 2    -0.021946

# %% [markdown]
# ---
#
# # Alternative Split Strategy: Primary Site-Based (Tissue Generalization)
#
# **Goal**: Test model's ability to generalize to **unseen tissue types**
#
# **Method**: Split by `primary site` - put rare tissue origins in test set
# - Train on common tissues (e.g., lung, blood, digestive system)
# - Test on rare tissues the model has never seen (e.g., thyroid, soft tissue, pancreas)
#
# **Rationale**: This tests a different kind of generalization:
# - **Histology-based**: Can the model predict drug response for a rare cancer subtype?
# - **Site-based**: Can the model predict drug response for a completely different organ/tissue?
#
# **Threshold**: 40% of site types → ~14.5% of samples in test set

# %%
# Primary Site distribution
site_counts = df.loc[y_subset.index, 'primary site'].value_counts(ascending=True)
print("Primary Site distribution (ascending by count):")
print(site_counts)
print(f"\nTotal sites: {len(site_counts)}")

# %%
# Primary Site-based split (40% of sites = rarest tissues go to test)
SITE_SPLIT_THRESHOLD = 0.4

site_split_index = int(len(site_counts) * SITE_SPLIT_THRESHOLD)
test_sites = site_counts.index[:site_split_index]  # Rarest tissue types
train_sites = site_counts.index[site_split_index:]  # More common tissues

print(f"Splitting {len(site_counts)} tissue sites at {SITE_SPLIT_THRESHOLD*100:.0f}% threshold")
print(f"Test sites: {site_split_index} (tissues model has NEVER seen)")
print(f"Train sites: {len(site_counts) - site_split_index}")

# Create feature set (methylation + expression only, no site info as feature)
feature_cols_site = methylation_cols + expression_cols
X_site = df[feature_cols_site].loc[y_subset.index].dropna(axis=1)
y_site = y_subset.loc[X_site.index]

# Get site labels for splitting
site_labels = df.loc[X_site.index, 'primary site']

X_train_site = X_site[site_labels.isin(train_sites)]
y_train_site = y_site[X_train_site.index]
X_test_site = X_site[site_labels.isin(test_sites)]
y_test_site = y_site[X_test_site.index]

print(f"\nTrain samples: {len(X_train_site)} ({len(X_train_site)/len(X_site)*100:.1f}%)")
print(f"Test samples: {len(X_test_site)} ({len(X_test_site)/len(X_site)*100:.1f}%)")
print(f"\nTest sites: {list(test_sites)}")

# %%
# Scale and PCA transform for site-based split
pca_site = PCA(n_components=15)
scaler_site = RobustScaler()

X_train_site_scaled = scaler_site.fit_transform(X_train_site)
X_train_site_scaled = pca_site.fit_transform(X_train_site_scaled)

X_test_site_scaled = scaler_site.transform(X_test_site)
X_test_site_scaled = pca_site.transform(X_test_site_scaled)

print(f"Scaled & PCA transformed:")
print(f"X_train_site_scaled: {X_train_site_scaled.shape}")
print(f"X_test_site_scaled: {X_test_site_scaled.shape}")

# %%
# Benchmark results for site-based split
benchmark_results_site = pd.DataFrame(columns=['Model', 'training MSE', 'average testing MSE', 'training R^2', 'testing R^2'])

# %% [markdown]
# ## XGBoost on Site-Based Split

# %%
# XGBoost with PCA on site-based split
from xgboost import XGBRegressor

xgb_site = XGBRegressor(random_state=42, tree_method='hist', device='cuda')
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}
search_site = HalvingRandomSearchCV(
    xgb_site, param_grid, factor=2,
    min_resources=50, max_resources=300, scoring='neg_mean_absolute_error',
    cv=3, n_jobs=1, verbose=1, random_state=42
)
search_site.fit(X_train_site_scaled, y_train_site)
print(f"Best params: {search_site.best_params_}")
print(f"Best score: {search_site.best_score_}")

# %%
benchmark_results_site.loc[len(benchmark_results_site)] = add_benchmark_result(
    search_site.best_estimator_, 'XGBoost w/ PCA (Site Split)', 
    X_test_site_scaled, y_test_site, X_train_site_scaled, y_train_site
)
benchmark_results_site

# %% [markdown]
# ## Random Forest on Site-Based Split

# %%
# Random Forest with PCA on site-based split
rf_site = RandomForestRegressor(random_state=42, n_jobs=-1)
param_dist = {
    "n_estimators": randint(50, 300),
    "max_depth": randint(3, 30),
    "min_samples_split": randint(2, 10),
    "min_samples_leaf": randint(1, 6),
    "max_features": uniform(0.3, 0.7),
    "bootstrap": [True, False],
}
search_rf_site = HalvingRandomSearchCV(
    rf_site, param_dist, factor=2,
    min_resources=50, max_resources=300, scoring='neg_mean_absolute_error',
    cv=3, n_jobs=-1, verbose=1, random_state=42
)
search_rf_site.fit(X_train_site_scaled, y_train_site)
print(f"Best params: {search_rf_site.best_params_}")
print(f"Best score: {search_rf_site.best_score_}")

# %%
benchmark_results_site.loc[len(benchmark_results_site)] = add_benchmark_result(
    search_rf_site.best_estimator_, 'Random Forest w/ PCA (Site Split)', 
    X_test_site_scaled, y_test_site, X_train_site_scaled, y_train_site
)
benchmark_results_site

# %% [markdown]
# ## Comparison: Histology vs Site-Based Splits
#
# Compare model performance across different generalization challenges:

# %%
print("=" * 70)
print("HISTOLOGY-BASED SPLIT (Rare cancer subtypes in test)")
print(f"Train: {len(X_train)} samples | Test: {len(X_test)} samples ({len(X_test)/len(X_subset)*100:.1f}%)")
print("=" * 70)
display(benchmark_results)

print("\n" + "=" * 70)
print("PRIMARY SITE-BASED SPLIT (Rare tissue types in test)")
print(f"Train: {len(X_train_site)} samples | Test: {len(X_test_site)} samples ({len(X_test_site)/len(X_site)*100:.1f}%)")
print("=" * 70)
display(benchmark_results_site)

print("\n" + "=" * 70)
print("INTERPRETATION")
print("=" * 70)
print("""
- Histology split: Tests generalization to UNSEEN CANCER SUBTYPES
  (e.g., can a model trained on melanoma predict for chondrosarcoma?)

- Site split: Tests generalization to UNSEEN TISSUE ORIGINS  
  (e.g., can a model trained on lung/blood predict for thyroid/pancreas?)

- Lower R² on test = harder generalization challenge
- Negative R² = model performs worse than predicting the mean
""")
